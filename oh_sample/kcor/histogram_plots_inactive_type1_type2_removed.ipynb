# %%
# %matplotlib inline
import numpy as N
import matplotlib.pyplot as P
import time
import os
import matplotlib.cm as cm
from prefig import *
from scipy.stats import kde
import matplotlib.colors as mcolors
from scipy.stats import mode
from scipy.interpolate import interp2d

# %%
font = {'family':'serif', 'size':16}
P.rc('font', **font)
P.rc('xtick', labelsize='medium')
P.rc('ytick', labelsize='medium')
P.rc('axes', labelsize='medium')


X = N.linspace(0, 14, 100)
Xs = X[:-1] + N.diff(X)
Y = N.linspace(0, 4, 100)
Ys = Y[:-1] + N.diff(Y)

ti = N.arange(0, 0.01, 0.003)
t = N.linspace(0,14.0,100)
time = N.append(ti, t[1:])

# %%
sumd = N.load('/Users/becky/Projects/followup_gv/bpt/sum_weight_low_mass_inactive_type1_type2_removed_sample_disc_log_weight.npy')
sums = N.load('/Users/becky/Projects/followup_gv/bpt/sum_weight_low_mass_inactive_type1_type2_removed_sample_smooth_log_weight.npy')

agnli = N.nan_to_num(N.log10(sumd))
nagnli = N.nan_to_num(N.log10(sums))

agnli[agnli < 0] = 0
nagnli[nagnli < 0] = 0

sumdli = agnli
sumsli = nagnli

xs = N.sum(sumsli, axis=1)
xs[xs == -N.inf] = N.min(xs[xs != -N.inf])
xsli = (xs-N.min(xs))/(N.max(xs)-N.min(xs))

ys = N.sum(sumsli, axis=0)
#ys[ys == -N.inf] = N.min(ys[ys != -N.inf])
ysli = (ys-N.min(ys))/(N.max(ys)-N.min(ys))

ysrli = (N.sum(ysli[N.where(Ys < 1.0)])/N.sum(ysli))*100
ysili =  (N.sum(ysli[N.where(N.logical_and(Ys > 1.0, Ys < 2.0))])/N.sum(ysli))*100
yssli =  (N.sum(ysli[N.where(Ys > 2.0)])/N.sum(ysli))*100

xd = N.sum(sumdli, axis=1)
xd[xd == -N.inf] = N.min(xd[xd != -N.inf])
xdli = (xd-N.min(xd))/(N.max(xd)-N.min(xd))
yd = N.sum(sumdli, axis=0)
yd[yd == -N.inf] = N.min(yd[yd != -N.inf])
ydli = (yd-N.min(yd))/(N.max(yd)-N.min(yd))

ydrli = (N.sum(ydli[N.where(Ys < 1.0)])/N.sum(ydli))*100
ydili =  (N.sum(ydli[N.where(N.logical_and(Ys > 1.0, Ys < 2.0))])/N.sum(ydli))*100
ydsli =  (N.sum(ydli[N.where(Ys > 2.0)])/N.sum(ydli))*100
# Out:
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:4: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:4: RuntimeWarning: invalid value encountered in log10
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:5: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:5: RuntimeWarning: invalid value encountered in log10

# %%
sumd = N.load('/Users/becky/Projects/followup_gv/bpt/sum_weight_med_mass_inactive_type1_type2_removed_sample_disc_log_weight.npy')
sums = N.load('/Users/becky/Projects/followup_gv/bpt/sum_weight_med_mass_inactive_type1_type2_removed_sample_smooth_log_weight.npy')

agnmi = N.nan_to_num(N.log10(sumd))
nagnmi = N.nan_to_num(N.log10(sums))

agnmi[agnmi < 0] = 0
nagnmi[nagnmi < 0] = 0

sumdmi = agnmi
sumsmi = nagnmi

xs = N.sum(sumsmi, axis=1)
xs[xs == -N.inf] = N.min(xs[xs != -N.inf])
xsmi = (xs-N.min(xs))/(N.max(xs)-N.min(xs))
ys = N.sum(sumsmi, axis=0)
ys[ys == -N.inf] = N.min(ys[ys != -N.inf])
ysmi = (ys-N.min(ys))/(N.max(ys)-N.min(ys))

ysrmi = (N.sum(ysmi[N.where(Ys < 1.0)])/N.sum(ysmi))*100
ysimi =  (N.sum(ysmi[N.where(N.logical_and(Ys > 1.0, Ys < 2.0))])/N.sum(ysmi))*100
yssmi =  (N.sum(ysmi[N.where(Ys > 2.0)])/N.sum(ysmi))*100

xd = N.sum(sumdmi, axis=1)
xd[xd == -N.inf] = N.min(xd[xd != -N.inf])
xdmi = (xd-N.min(xd))/(N.max(xd)-N.min(xd))
yd = N.sum(sumdmi, axis=0)
yd[yd == -N.inf] = N.min(yd[yd != -N.inf])
ydmi = (yd-N.min(yd))/(N.max(yd)-N.min(yd))

ydrmi = (N.sum(ydmi[N.where(Ys < 1.0)])/N.sum(ydmi))*100
ydimi =  (N.sum(ydmi[N.where(N.logical_and(Ys > 1.0, Ys < 2.0))])/N.sum(ydmi))*100
ydsmi =  (N.sum(ydmi[N.where(Ys > 2.0)])/N.sum(ydmi))*100
# Out:
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:4: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:4: RuntimeWarning: invalid value encountered in log10
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:5: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:5: RuntimeWarning: invalid value encountered in log10

# %%
sumd = N.load('/Users/becky/Projects/followup_gv/bpt/sum_weight_high_mass_inactive_type1_type2_removed_sample_disc_log_weight.npy')
sums = N.load('/Users/becky/Projects/followup_gv/bpt/sum_weight_high_mass_inactive_type1_type2_removed_sample_smooth_log_weight.npy')

agnhi = N.nan_to_num(N.log10(sumd))
nagnhi = N.nan_to_num(N.log10(sums))

agnhi[agnhi < 0] = 0
nagnhi[nagnhi < 0] = 0

sumdhi = agnhi
sumshi = nagnhi

xs = N.sum(sumshi, axis=1)
xs[xs == -N.inf] = N.min(xs[xs != -N.inf])
xshi = (xs-N.min(xs))/(N.max(xs)-N.min(xs))
ys = N.sum(sumshi, axis=0)
ys[ys == -N.inf] = N.min(ys[ys != -N.inf])
yshi = (ys-N.min(ys))/(N.max(ys)-N.min(ys))

ysrhi = (N.sum(yshi[N.where(Ys < 1.0)])/N.sum(yshi))*100
ysihi =  (N.sum(yshi[N.where(N.logical_and(Ys > 1.0, Ys < 2.0))])/N.sum(yshi))*100
ysshi =  (N.sum(yshi[N.where(Ys > 2.0)])/N.sum(yshi))*100

xd = N.sum(sumdhi, axis=1)
xd[xd == -N.inf] = N.min(xd[xd != -N.inf])
xdhi = (xd-N.min(xd))/(N.max(xd)-N.min(xd))
yd = N.sum(sumdhi, axis=0)
yd[yd == -N.inf] = N.min(yd[yd != -N.inf])
ydhi = (yd-N.min(yd))/(N.max(yd)-N.min(yd))

ydrhi = (N.sum(ydhi[N.where(Ys < 1.0)])/N.sum(ydhi))*100
ydihi =  (N.sum(ydhi[N.where(N.logical_and(Ys > 1.0, Ys < 2.0))])/N.sum(ydhi))*100
ydshi =  (N.sum(ydhi[N.where(Ys > 2.0)])/N.sum(ydhi))*100
# Out:
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:4: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:4: RuntimeWarning: invalid value encountered in log10
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:5: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:5: RuntimeWarning: invalid value encountered in log10

# %%
sumd = N.load('/Users/becky/Projects/followup_gv/bpt/sum_weight_high_mass_bpt_type2_agn_hardcut_disc_log_weight.npy')
sums = N.load('/Users/becky/Projects/followup_gv/bpt/sum_weight_high_mass_bpt_type2_agn_hardcut_smooth_log_weight.npy')

agnha = N.nan_to_num(N.log10(sumd))
nagnha = N.nan_to_num(N.log10(sums))

agnha[agnha < 0] = 0
nagnha[nagnha < 0] = 0

sumdha = agnha
sumsha = nagnha

xs = N.sum(sumsha, axis=1)
xsha = (xs-N.min(xs))/(N.max(xs)-N.min(xs))
ys = N.sum(sumsha, axis=0)
ysha = (ys-N.min(ys))/(N.max(ys)-N.min(ys))

ysrha = (N.sum(ysha[N.where(Ys < 1.0)])/N.sum(ysha))*100
ysiha =  (N.sum(ysha[N.where(N.logical_and(Ys > 1.0, Ys < 2.0))])/N.sum(ysha))*100
yssha =  (N.sum(ysha[N.where(Ys > 2.0)])/N.sum(ysha))*100

xd = N.sum(sumdha, axis=1)
xdha = (xd-N.min(xd))/(N.max(xd)-N.min(xd))
yd = N.sum(sumdha, axis=0)
ydha = (yd-N.min(yd))/(N.max(yd)-N.min(yd))

ydrha = (N.sum(ydha[N.where(Ys < 1.0)])/N.sum(ydha))*100
ydiha =  (N.sum(ydha[N.where(N.logical_and(Ys > 1.0, Ys < 2.0))])/N.sum(ydha))*100
ydsha =  (N.sum(ydha[N.where(Ys > 2.0)])/N.sum(ydha))*100
# Out:
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:4: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:4: RuntimeWarning: invalid value encountered in log10
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:5: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:5: RuntimeWarning: invalid value encountered in log10

# %%
sumd = N.load('/Users/becky/Projects/followup_gv/bpt/sum_weight_med_mass_bpt_type2_agn_hardcut_disc_log_weight.npy')
sums = N.load('/Users/becky/Projects/followup_gv/bpt/sum_weight_med_mass_bpt_type2_agn_hardcut_smooth_log_weight.npy')

agnma = N.nan_to_num(N.log10(sumd))
nagnma = N.nan_to_num(N.log10(sums))

agnma[agnma < 0] = 0
nagnma[nagnma < 0] = 0

sumdma = agnma
sumsma = nagnma

xs = N.sum(sumsma, axis=1)
xsma = (xs-N.min(xs))/(N.max(xs)-N.min(xs))
ys = N.sum(sumsma, axis=0)
ysma = (ys-N.min(ys))/(N.max(ys)-N.min(ys))

ysrma = (N.sum(ysma[N.where(Ys < 1.0)])/N.sum(ysma))*100
ysima =  (N.sum(ysma[N.where(N.logical_and(Ys > 1.0, Ys < 2.0))])/N.sum(ysma))*100
yssma =  (N.sum(ysma[N.where(Ys > 2.0)])/N.sum(ysma))*100

xd = N.sum(sumdma, axis=1)
xdma = (xd-N.min(xd))/(N.max(xd)-N.min(xd))
yd = N.sum(sumdma, axis=0)
ydma = (yd-N.min(yd))/(N.max(yd)-N.min(yd))

ydrma = (N.sum(ydma[N.where(Ys < 1.0)])/N.sum(ydma))*100
ydima =  (N.sum(ydma[N.where(N.logical_and(Ys > 1.0, Ys < 2.0))])/N.sum(ydma))*100
ydsma =  (N.sum(ydma[N.where(Ys > 2.0)])/N.sum(ydma))*100
# Out:
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:4: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:4: RuntimeWarning: invalid value encountered in log10
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:5: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:5: RuntimeWarning: invalid value encountered in log10

# %%
sumd = N.load('/Users/becky/Projects/followup_gv/bpt/sum_weight_low_mass_bpt_type2_agn_hardcut_disc_log_weight.npy')
sums = N.load('/Users/becky/Projects/followup_gv/bpt/sum_weight_low_mass_bpt_type2_agn_hardcut_smooth_log_weight.npy')

agnla = N.nan_to_num(N.log10(sumd))
nagnla = N.nan_to_num(N.log10(sums))

agnla[agnla < 0] = 0
nagnla[nagnla < 0] = 0

sumdla = agnla
sumsla = nagnla

xs = N.sum(sumsla, axis=1)
xsla = (xs-N.min(xs))/(N.max(xs)-N.min(xs))
ys = N.sum(sumsla, axis=0)
ysla = (ys-N.min(ys))/(N.max(ys)-N.min(ys))

ysrla = (N.sum(ysla[N.where(Ys < 1.0)])/N.sum(ysla))*100
ysila =  (N.sum(ysla[N.where(N.logical_and(Ys > 1.0, Ys < 2.0))])/N.sum(ysla))*100
yssla =  (N.sum(ysla[N.where(Ys > 2.0)])/N.sum(ysla))*100

xd = N.sum(sumdla, axis=1)
xdla = (xd-N.min(xd))/(N.max(xd)-N.min(xd))
yd = N.sum(sumdla, axis=0)
ydla = (yd-N.min(yd))/(N.max(yd)-N.min(yd))

ydrla = (N.sum(ydla[N.where(Ys < 1.0)])/N.sum(ydla))*100
ydila =  (N.sum(ydla[N.where(N.logical_and(Ys > 1.0, Ys < 2.0))])/N.sum(ydla))*100
ydsla =  (N.sum(ydla[N.where(Ys > 2.0)])/N.sum(ydla))*100
# Out:
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:4: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:4: RuntimeWarning: invalid value encountered in log10
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:5: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:5: RuntimeWarning: invalid value encountered in log10

# %%
from mpl_toolkits.axes_grid1 import ImageGrid
from prefig import Prefig
Prefig(size=(15,10.5), axcol='w', fontcol='w')
#F = P.figure(figsize=(10,7))
ax1 = P.subplot2grid((3,2), (0,0))
ax1.hist(Xs, weights = xsla, bins=Xs, histtype='step', color='m')
ax1.hist(Xs, weights = xdla, bins=Xs, histtype='step', color='y')
ax1.set_xlim(0.1, 13.8)
ax1.text(1.2, 0.9, 'Low Mass AGN Hosts')
ax1.text(1.2, 0.8, 'Disc', color='y')
ax1.text(1.2, 0.7, 'Smooth', color='m')
ax1.set_ylim(0, 1.1)
ax12 = ax1.twiny()
ax12.set_xlim(0.1, 13.8)
ax12.set_xticks(N.array([1.87, 3.40, 6.03, 8.77, 10.9, 12.5]))
ax12.set_xticklabels(N.array([3.5, 2.0 , 1.0, 0.5, 0.25, 0.1]))
ax12.tick_params(axis='x', labelbottom='off', bottom='off')
ax1.tick_params('x', labelbottom='off', labeltop='off')
ax12.set_xlabel(r'$z$')
ax2 = P.subplot2grid((3,2), (1,0))
ax2.hist(Xs, weights = xsma, bins=Xs, histtype='step', color='m')
ax2.hist(Xs, weights = xdma, bins=Xs, histtype='step', color='y')
ax2.set_xlim(0.1, 13.8)
ax2.text(1.2, 0.9, 'Medium Mass AGN Hosts')
ax2.text(1.2, 0.8, 'Disc', color='y')
ax2.text(1.2, 0.7, 'Smooth', color='m')
ax2.tick_params('x', labelbottom='off')
ax2.set_ylim(0, 1.1)
ax2.set_ylabel('normalised 1D likelihood distribution')
ax3 = P.subplot2grid((3,2), (2,0))
ax3.hist(Xs, weights = xsha, bins=Xs, histtype='step', color='m')
ax3.hist(Xs, weights = xdha, bins=Xs, histtype='step', color='y')
ax3.set_xlim(0.1, 13.8)
ax3.set_ylim(0, 1.1)
ax3.text(1.2, 0.9, 'High Mass AGN Hosts')
ax3.text(1.2, 0.8, 'Disc', color='y')
ax3.text(1.2, 0.7, 'Smooth', color='m')
ax3.set_xlabel('$t_q$ [Gyr]')
ax4 = P.subplot2grid((3,2), (0,1))
ax4.hist(Xs, weights = xsli, bins=Xs, histtype='step', color='m')
ax4.hist(Xs, weights = xdli, bins=Xs, histtype='step', color='y')
ax4.set_xlim(0.1, 13.8)
ax4.set_ylim(0, 1.1)
ax4.text(1.2, 0.25, 'Low Mass Inactive Galaxies')
ax4.text(1.2, 0.15, 'Disc', color='y')
ax4.text(1.2, 0.05, 'Smooth', color='m')
ax12 = ax4.twiny()
ax12.set_xlim(0.1, 13.8)
ax12.set_xticks(N.array([1.87, 3.40, 6.03, 8.77, 10.9, 12.5]))
ax12.set_xticklabels(N.array([3.5, 2.0 , 1.0, 0.5, 0.25, 0.1]))
ax12.tick_params(axis='x', labelbottom='off')
ax12.set_xlabel(r'$z$')
ax4.tick_params('both', labelbottom='off', labelleft='off')
ax5 = P.subplot2grid((3,2), (1,1))
ax5.hist(Xs, weights = xsmi, bins=Xs, histtype='step', color='m')
ax5.hist(Xs, weights = xdmi, bins=Xs, histtype='step', color='y')
ax5.set_xlim(0.1, 13.8)
ax5.set_ylim(0, 1.1)
ax5.text(1.2, 0.25, 'Medium Mass Inactive Galaxies')
ax5.text(1.2, 0.15, 'Disc', color='y')
ax5.text(1.2, 0.05, 'Smooth', color='m')
ax5.tick_params('both', labelbottom='off', labelleft='off')
#ax5.set_xlabel('$t_q \rm{[Gyr]}$')
ax6 = P.subplot2grid((3,2), (2,1))
ax6.hist(Xs, weights = xshi, bins=Xs, histtype='step', color='m')
ax6.hist(Xs, weights = xdhi, bins=Xs, histtype='step', color='y')
ax6.set_xlim(0.1, 13.8)
ax6.set_ylim(0, 1.1)
ax6.text(1.2, 0.25, 'High Mass Inactive Galaxies')
ax6.text(1.2, 0.15, 'Disc', color='y')
ax6.text(1.2, 0.05, 'Smooth', color='m')
ax6.set_xlabel('$t_q$ [Gyr]')
ax6.tick_params('y', labelleft='off')
# ax_l = F.add_axes([0.01, 0.42, 0.005, 0.2])
# ax_l.spines['top'].set_visible(False)
# ax_l.spines['bottom'].set_visible(False)
# ax_l.spines['right'].set_visible(False)
# ax_l.spines['left'].set_visible(False)
# ax_l.tick_params('both', bottom='off', top='off', right='off', left='off', labelbottom='off', labelleft='off')
# ax_l.set_ylabel('normalised 1D probability distribution')
P.tight_layout()
P.subplots_adjust(left =0.1, wspace=0.0, hspace=0.0)
P.savefig('quenching_time_histograms_smooth_red_disc_blue_vertical_bpt_type2_agn_hardcut_inactive_type1_type2_removed_prefig.png')

# %%
from mpl_toolkits.axes_grid1 import ImageGrid
from prefig import Prefig
#F = P.figure(figsize=(10,7))
Prefig(size=(15,10.5), axcol='w', fontcol='w')
ax1 = P.subplot2grid((3,2), (0,0))
ax1.hist(Ys, weights = ysla, bins=Ys, histtype='step', color='m')
ax1.hist(Ys, weights = ydla, bins=Ys, histtype='step', color='y')
ax1.set_xlim(0.2, 4.0)
ax1.set_ylim(0, 1.1)
ax1.text(3.9, 0.9, 'Low Mass AGN Hosts', ha='right')
ax1.text(3.9, 0.8, 'Disc', color='y', ha='right')
ax1.text(3.9, 0.7, 'Smooth', color='m', ha='right')
ax1.tick_params('x', labelbottom='off')
ax1.axvline(x=1.0, linestyle='dashed', color='w', alpha=0.5)
ax1.axvline(x=2.0, linestyle='dashed', color='w', alpha=0.5)
ax1.text(0.35, 0.5, '%3.1f' % ydrla+'%', color='y')
ax1.text(1.35, 0.5, '%3.1f' % ydila+'%', color='y')
ax1.text(2.35, 0.5, '%3.1f' % ydsla+'%', color='y')
ax1.text(0.35, 0.4, '%3.1f' % ysrla+'%', color='m')
ax1.text(1.35, 0.4, '%3.1f' % ysila+'%', color='m')
ax1.text(2.35, 0.4, '%3.1f' % yssla+'%', color='m')
ax2 = P.subplot2grid((3,2), (1,0))
ax2.hist(Ys, weights = ysma, bins=Ys, histtype='step', color='m')
ax2.hist(Ys, weights = ydma, bins=Ys, histtype='step', color='y')
ax2.set_xlim(0.2, 4.0)
ax2.set_ylim(0, 1.1)
ax2.text(3.9, 0.9, 'Medium Mass AGN Hosts', ha='right')
ax2.text(3.9, 0.8, 'Disc', color='y', ha='right')
ax2.text(3.9, 0.7, 'Smooth', color='m', ha='right')
ax2.tick_params('x', labelbottom='off')
ax2.set_ylabel('normalised 1D likelihood distribution')
ax2.axvline(x=1.0, linestyle='dashed', color='w', alpha=0.5)
ax2.axvline(x=2.0, linestyle='dashed', color='w', alpha=0.5)
ax2.text(0.35, 0.2, '%3.1f' % ydrma+'%', color='y')
ax2.text(1.35, 0.2, '%3.1f' % ydima+'%', color='y')
ax2.text(2.35, 0.2, '%3.1f' % ydsma+'%', color='y')
ax2.text(0.35, 0.1, '%3.1f' % ysrma+'%', color='m')
ax2.text(1.35, 0.1, '%3.1f' % ysima+'%', color='m')
ax2.text(2.35, 0.1, '%3.1f' % yssma+'%', color='m')
ax3 = P.subplot2grid((3,2), (2,0))
ax3.set_xlim(0.2, 4.0)
ax3.set_ylim(0, 1.1)
ax3.text(3.9, 0.9, 'High Mass AGN Hosts', ha='right')
ax3.text(3.9, 0.8, 'Disc', color='y', ha='right')
ax3.text(3.9, 0.7, 'Smooth', color='m', ha='right')
ax3.axvline(x=1.0, linestyle='dashed', color='w', alpha=0.5)
ax3.axvline(x=2.0, linestyle='dashed', color='w', alpha=0.5)
ax3.text(0.35, 0.2, '%3.1f' % ydrha+'%', color='y')
ax3.text(1.35, 0.2, '%3.1f' % ydiha+'%', color='y')
ax3.text(2.35, 0.2, '%3.1f' % ydsha+'%', color='y')
ax3.text(0.35, 0.1, '%3.1f' % ysrha+'%', color='m')
ax3.text(1.35, 0.1, '%3.1f' % ysiha+'%', color='m')
ax3.text(2.35, 0.1, '%3.1f' % yssha+'%', color='m')
ax3.hist(Ys, weights = ysha, bins=Ys, histtype='step', color='m')
ax3.hist(Ys, weights = ydha, bins=Ys, histtype='step', color='y')
ax3.set_xlabel(r'$\tau $ [Gyr]')
ax4 = P.subplot2grid((3,2), (0,1))
ax4.hist(Ys, weights = ysli, bins=Ys, histtype='step', color='m')
ax4.hist(Ys, weights = ydli, bins=Ys, histtype='step', color='y')
ax4.set_xlim(0.2, 4.0)
ax4.text(3.9, 0.9, 'Low Mass Inactive Galaxies', ha='right')
ax4.text(3.9, 0.8, 'Disc', color='y', ha='right')
ax4.text(3.9, 0.7, 'Smooth', color='m', ha='right')
ax4.tick_params('both', labelbottom='off', labelleft='off')
ax4.set_ylim(0, 1.1)
ax4.axvline(x=1.0, linestyle='dashed', color='w', alpha=0.5)
ax4.axvline(x=2.0, linestyle='dashed', color='w', alpha=0.5)
ax4.text(0.35, 0.2, '%3.1f' % ydrli+'%', color='y')
ax4.text(1.35, 0.2, '%3.1f' % ydili+'%', color='y')
ax4.text(2.35, 0.2, '%3.1f' % ydsli+'%', color='y')
ax4.text(0.35, 0.1, '%3.1f' % ysrli+'%', color='m')
ax4.text(1.35, 0.1, '%3.1f' % ysili+'%', color='m')
ax4.text(2.35, 0.1, '%3.1f' % yssli+'%', color='m')
ax5 = P.subplot2grid((3,2), (1,1))
ax5.hist(Ys, weights = ysmi, bins=Ys, histtype='step', color='m')
ax5.hist(Ys, weights = ydmi, bins=Ys, histtype='step', color='y')
ax5.set_xlim(0.2, 4.0)
ax5.text(3.9, 0.9, 'Medium Mass Inactive Galaxies', ha='right')
ax5.text(3.9, 0.8, 'Disc', color='y', ha='right')
ax5.text(3.9, 0.7, 'Smooth', color='m', ha='right')
ax5.tick_params('both', labelbottom='off', labelleft='off')
ax5.set_ylim(0, 1.1)
ax5.axvline(x=1.0, linestyle='dashed', color='w', alpha=0.5)
ax5.axvline(x=2.0, linestyle='dashed', color='w', alpha=0.5)
ax5.text(0.35, 0.2, '%3.1f' % ydrmi+'%', color='y')
ax5.text(1.35, 0.2, '%3.1f' % ydimi+'%', color='y')
ax5.text(2.35, 0.2, '%3.1f' % ydsmi+'%', color='y')
ax5.text(0.35, 0.1, '%3.1f' % ysrmi+'%', color='m')
ax5.text(1.35, 0.1, '%3.1f' % ysimi+'%', color='m')
ax5.text(2.35, 0.1, '%3.1f' % yssmi+'%', color='m')
#ax5.set_xlabel('$t_q \rm{[Gyr]}$')
ax6 = P.subplot2grid((3,2), (2,1))
ax6.tick_params('y', labelleft='off')
ax6.hist(Ys, weights = yshi, bins=Ys, histtype='step', color='m')
ax6.hist(Ys, weights = ydhi, bins=Ys, histtype='step', color='y')
ax6.set_xlim(0.2, 4.0)
ax6.text(3.9, 0.9, 'High Mass Inactive Galaxies', ha='right')
ax6.text(3.9, 0.8, 'Disc', color='y', ha='right')
ax6.text(3.9, 0.7, 'Smooth', color='m', ha='right')
ax6.set_xlabel(r'$\tau $ [Gyr]')
ax6.set_ylim(0, 1.1)
ax6.axvline(x=1.0, linestyle='dashed', color='w', alpha=0.5)
ax6.axvline(x=2.0, linestyle='dashed', color='w', alpha=0.5)
ax6.text(0.35, 0.2, '%3.1f' % ydrhi+'%', color='y')
ax6.text(1.35, 0.2, '%3.1f' % ydihi+'%', color='y')
ax6.text(2.35, 0.2, '%3.1f' % ydshi+'%', color='y')
ax6.text(0.35, 0.1, '%3.1f' % ysrhi+'%', color='m')
ax6.text(1.35, 0.1, '%3.1f' % ysihi+'%', color='m')
ax6.text(2.35, 0.1, '%3.1f' % ysshi+'%', color='m')
# ax_l = F.add_axes([0.01, 0.42, 0.005, 0.2])
# ax_l.spines['top'].set_visible(False)
# ax_l.spines['bottom'].set_visible(False)
# ax_l.spines['right'].set_visible(False)
# ax_l.spines['left'].set_visible(False)
# ax_l.tick_params('both', bottom='off', top='off', right='off', left='off', labelbottom='off', labelleft='off')
# ax_l.set_ylabel('normalised 1D probability distribution')
P.tight_layout()
P.subplots_adjust(wspace=0.00, hspace=0.0)
P.savefig('quenching_rate_histograms_smooth_red_disc_blue_vertical_bpt_type2_agn_hardcut_inactive_type1_type2_removed_prefig.png')
